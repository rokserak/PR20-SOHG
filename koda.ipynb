# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
plt.style.use('ggplot')

gospodinsta_dataframe=pd.read_csv('podatki/gospodinstva.csv', sep=',',header=1)
gospodinstva = gospodinsta_dataframe.values
gospodinstva[1]
list(gospodinstva[1][2:-1])
# plt.Figure()
# plt.rcParams["figure.figsize"] = (18,5)

vrednost =  list(gospodinstva[4][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)

plt.xlabel("Leta")
plt.ylabel(gospodinstva[4][1])
plt.title(gospodinstva[4][0])
plt.xticks(rotation=90)
plt.show()


plt.Figure()
plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[5][3:-1]))
plt.xlabel("Leta")
plt.ylabel(gospodinstva[5][1])
plt.title(gospodinstva[5][0])

plt.show()

# %%
plt.Figure()

vrednost =  list(gospodinstva[16][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)
plt.xlabel("Leta")
plt.ylabel(gospodinstva[16][1])
plt.title(gospodinstva[16][0])
plt.xticks(rotation=90)
plt.show()



ySkala =  []
for x in np.arange(0.0, 9.0,0.1):
    ySkala.append(x)
plt.Figure()

plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[20][3:-1]), )
plt.xlabel("Leta")

plt.ylabel(gospodinstva[20][1])
plt.title(gospodinstva[20][0])

plt.show()

# %%
plt.Figure()

vrednost =  list(gospodinstva[51][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)
plt.xlabel("Leta")
plt.ylabel(gospodinstva[51][1])
plt.title(gospodinstva[51][0])
plt.xticks(rotation=90)
plt.show()



plt.Figure()

plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[55][3:-1]), )
plt.xlabel("Leta")

plt.ylabel(gospodinstva[55][1])
plt.title(gospodinstva[55][0])

plt.show()

# %%
plt.Figure()

vrednost =  list(gospodinstva[116][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)
plt.xlabel("Leta")
plt.ylabel(gospodinstva[116][1])
plt.title(gospodinstva[116][0])
plt.xticks(rotation=90)
plt.show()


plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[120][3:-1]), )
plt.xlabel("Leta")

plt.ylabel(gospodinstva[120][1])
plt.title(gospodinstva[120][0])

plt.show()

# %%
plt.Figure()

vrednost =  list(gospodinstva[141][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)
plt.xlabel("Leta")
plt.ylabel(gospodinstva[141][1])
plt.title(gospodinstva[141][0])
plt.xticks(rotation=90)

plt.show()


plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[145][3:-1]), )
plt.xlabel("Leta")

plt.ylabel(gospodinstva[145][1])
plt.title(gospodinstva[145][0])

plt.show()

# %%
plt.Figure()

vrednost =  list(gospodinstva[261][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"o", list(gospodinstva[0][2:-1]),vrednost)

plt.xlabel("Leta")
plt.ylabel(gospodinstva[261][1])
plt.title(gospodinstva[261][0][2:])
plt.xticks(rotation=90)

plt.show()

plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[265][3:-1]), )
plt.xlabel("Leta")

plt.ylabel(gospodinstva[265][1])
plt.title(gospodinstva[265][0][2:])

plt.show()

# %%
# plt.Figure()

vrednost =  list(gospodinstva[211][2:-1])
vrednost[0] = float(vrednost[0])

plt.plot(list(gospodinstva[0][2:-1]),vrednost,"bo", list(gospodinstva[0][2:-1]),vrednost)

plt.xlabel("Leta")
plt.ylabel(gospodinstva[211][1])
plt.title("Izobraževanje")
plt.xticks(rotation=90)

plt.show()

plt.plot(list(gospodinstva[0][3:-1]),list(gospodinstva[215][3:-1]), )
plt.xlabel("Leta")
plt.ylabel(gospodinstva[215][1])
plt.title("Izobraževanje")

plt.show()

# %%
inflacija_df = pd.read_csv('podatki/inflacija.csv', sep=',', header=1, encoding='windows-1250')
inflacija_jan = [inflacija_df.loc[0][i] / 100 for i in range(13, inflacija_df.loc[0][13:].size, 12)]

def calc_inflation(i, j):
    inflation = 1
    for k in range(i, j + 1):
        inflation *= inflacija_jan[k]
    return inflation * 100

inflacija_jan = [calc_inflation(0, i) - 100 for i in range(len(inflacija_jan))]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8))

vrednost =  list(gospodinstva[211][2:-1])
vrednost[0] = float(vrednost[0])

leta = [str(int(i)) for i in gospodinstva[0][2:-1]]

#izobraževanje
ax1.plot(leta,vrednost, label="Izobraževanje")
ax1.plot(leta,vrednost,"o", markersize=3)


#hoes
vrednost =  list(gospodinstva[261][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta, vrednost , label="Prostitucija")
ax1.plot(leta, vrednost,"o", markersize=3)


#auto
vrednost =  list(gospodinstva[141][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta,vrednost , label="Prevozna sredstva")
ax1.plot(leta,vrednost,"o", markersize=3)


#zdravstvo
vrednost =  list(gospodinstva[116][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta,vrednost, label="Zdravstvo")
ax1.plot(leta,vrednost,"o", markersize=3)


#Stanovanja
vrednost = list(gospodinstva[56][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta,vrednost, label="Najemnine stanovanja")
ax1.plot(leta,vrednost,"o", markersize=3)

# Vzdrževanje Stanovanja
vrednost =  list(gospodinstva[66][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta,vrednost, label="Vzdrževanje stanovanja")
ax1.plot(leta,vrednost,"o", markersize=3)


# alko
vrednost =  list(gospodinstva[21][2:-1])
vrednost[0] = float(vrednost[0])

ax1.plot(leta,vrednost, label="Alkoholne pijače")
ax1.plot(leta,vrednost,"o", markersize=3)

ax1.set(xlabel='Leta', ylabel=gospodinstva[211][1], 
        title='Poraba gospodinjstev na različnih panogah \nbrez upoštevane inflacije')
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
ax1.legend()



vrednost =  list(gospodinstva[211][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

leta = [str(int(i)) for i in gospodinstva[0][2:-1]][5:]

#izobraževanje
plt.plot(leta,vrednost, label="Izobraževanje")
plt.plot(leta,vrednost,"o", markersize=3)


#hoes
vrednost =  list(gospodinstva[261][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta, vrednost , label="Prostitucija")
ax2.plot(leta, vrednost,"o", markersize=3)


#auto
vrednost =  list(gospodinstva[141][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta,vrednost , label="Prevozna sredstva")
ax2.plot(leta,vrednost,"o", markersize=3)


#zdravstvo
vrednost =  list(gospodinstva[116][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta,vrednost, label="Zdravstvo")
ax2.plot(leta,vrednost,"o", markersize=3)


#Stanovanja
vrednost = list(gospodinstva[56][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta,vrednost, label="Najemnine stanovanja")
ax2.plot(leta,vrednost,"o", markersize=3)

# Vzdrževanje Stanovanja
vrednost =  list(gospodinstva[66][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta,vrednost, label="Vzdrževanje stanovanja")
ax2.plot(leta,vrednost,"o", markersize=3)


# alko
vrednost =  list(gospodinstva[21][2:-1])
vrednost[0] = float(vrednost[0])
vrednost = vrednost[5:]
vrednost = [v - (v * infl / 100) for v, infl in zip(vrednost, inflacija_jan)]

ax2.plot(leta,vrednost, label="Alkoholne pijače")
ax2.plot(leta,vrednost,"o", markersize=3)


ax2.set(xlabel='Leta', ylabel=gospodinstva[211][1], 
        title='Poraba gospodinjstev na različnih panogah \nz upoštevano inflacijo')
for tick in ax2.get_xticklabels():
    tick.set_rotation(90)
ax2.legend()


plt.savefig('6.png')
plt.show()

# %%
alco =  list(gospodinstva[21][2:-1])
alco[0] = float(vrednost[0])

sok =  list(gospodinstva[11][2:-1])
sok[0] = float(vrednost[0])
plt.rcParams["figure.figsize"] = (10,5)
plt.scatter(alco, sok)
plt.xlim((100,450))
plt.ylim((100,450))
plt.xlabel("Alkohol")
plt.ylabel("Brezalkoholne pijače")
plt.plot([100,500],[100,500])
plt.title("Primerjava letnih stroškov alkoholnih in brezalkoholnih pijač")
plt.savefig('7.png')
plt.show()

# %%
zunaj =  list(gospodinstva[126][2:-1])
zunaj[0] = float(vrednost[0])

boln =  list(gospodinstva[131][2:-1])
boln[0] = float(vrednost[0])


plt.rcParams["figure.figsize"] = (15,10)
plt.scatter(zunaj, boln)
plt.xlim((5,400))
plt.ylim((5,400))
plt.xlabel("Zunaj bolnišnične storitve (Zdravilišča,rehabilitacije,fizioterapija,...)")
plt.ylabel("Bolnišnične storitve")
plt.plot([5,500],[5,500])
plt.title("Primerjava letnih stroškov bolnišničnih in zunaj bolnišničnih stroškov")

plt.show()

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
inflacija_df = pd.read_csv('podatki/inflacija.csv', sep=',', header=1, encoding='windows-1250')
gospodinstva_df=pd.read_csv('podatki/gospodinstva.csv', sep=',',header=1)

# %%
inflacija_skupaj = inflacija_df.loc[0][13:] - 100

plt.figure(figsize=(15, 8))
plt.plot(
    range(inflacija_skupaj.size),
    inflacija_skupaj
)
plt.title('Inflacija po mesecih od leta 2000 do 2019')
plt.xlabel('Mesec')
plt.ylabel('Inflacija (%)')
plt.show()

# %%
inflacija_jan = [inflacija_df.loc[0][i] / 100 for i in range(13, inflacija_df.loc[0][13:].size, 12)]

def calc_inflation(i, j):
    inflation = 1
    for k in range(i, j + 1):
        inflation *= inflacija_jan[k]
    return inflation * 100

inflacija_jan = [calc_inflation(0, i) - 100 for i in range(len(inflacija_jan))]

# %%
# inflacija_jan = [inflacija_df.loc[1][i] - 100 for i in range(13, inflacija_df.loc[1][13:].size, 12)]
# inflacija_jan = [sum(inflacija_jan[0:i]) for i in range(len(inflacija_jan))]

plt.figure(figsize=(15, 8))
plt.plot(
    [str(leto) for leto in range(2001, 2020)],
    inflacija_jan
)
plt.title('Inflacija od leta 2001 do 2019')
plt.xlabel('Leto')
plt.ylabel('Inflacija (%)')
plt.savefig('8.png')
plt.show()

# %%
cena_z_inflacijo = [
    float(cena) - float(cena) * inflacija / 100 for cena, inflacija
                                                in zip(gospodinstva_df.loc[1][7:-1], inflacija_jan)
]
# add for year 1999 with no inflation included
cena_z_inflacijo.insert(0, gospodinstva_df.loc[1][6])

plt.figure(figsize=(15, 8))
plt.plot(
    [str(leto) for leto in range(2000, 2019 + 1)],
    cena_z_inflacijo
)
plt.title('Poraba na hrani in brezalkoholnih pijačah čez leta z izključeno inflacijo')
plt.xlabel('Leto')
plt.ylabel('Poraba (mio €)')
plt.xticks(rotation='vertical')
plt.show()

# %%
cena_z_inflacijo = [
    float(cena) - float(cena) * inflacija / 100 for cena, inflacija
                                                in zip(gospodinstva_df.loc[1][7:-1], inflacija_jan)
]
# add for year 1999 with no inflation included
cena_z_inflacijo.insert(0, gospodinstva_df.loc[1][6])


#gospodinstva_df
vrstice = [1,17,37,52,82,117,139,157,179,212,237,252]
imena = []
for i in vrstice:
    imena.append(gospodinstva_df.loc[i][0])
podatkiBrezInflacije = []
for i in vrstice:
    cena_z_inflacijo = [
    float(cena) - float(cena) * inflacija / 100 for cena, inflacija
                                                in zip(gospodinstva_df.loc[i][7:-1], inflacija_jan)
    ]
    cena_z_inflacijo.insert(0, gospodinstva_df.loc[i][6])
    podatkiBrezInflacije.append(cena_z_inflacijo)

# %%
import scipy.cluster.hierarchy as sch
L = sch.linkage(podatkiBrezInflacije, method="average", metric="cosine")
plt.figure(figsize=(15, 7))
#labels = [row["name"].value for row in data]
D      = sch.dendrogram(L, labels=imena, orientation="left", leaf_font_size=15)
plt.xlabel("Razdalja")
plt.title('Gručenje dobrin glede na porabo skozi leta')
plt.tight_layout()
plt.savefig('5.png')
plt.show()

#Kosinusna razdalja (metric="cosine")
#Predstavlja kosinus kota med vektorjema  𝑥⃗   in  𝑦⃗   - manjši kot pomeni večjo podobnost. Uporabna za primerjavo podobnosti med vektorji, neupoštevajoč absolutnih #velikosti.

# %%
import scipy.cluster.hierarchy as sch
L = sch.linkage(podatkiBrezInflacije, method="average", metric="cityblock")

fig = plt.figure()
ax = fig.add_subplot()
# ax.set_xscale('log')

#labels = [row["name"].value for row in data]
D      = sch.dendrogram(L, labels=imena, orientation='left', leaf_font_size=15)
plt.xlabel("Razdalja")
plt.show()

# Kosinusna razdalja (metric="cosine")
# Predstavlja kosinus kota med vektorjema  𝑥⃗   in  𝑦⃗   - manjši kot pomeni večjo podobnost. 
# Uporabna za primerjavo podobnosti med vektorji, neupoštevajoč absolutnih #velikosti.

# %%
vrstice = [1,17,37,52,82,117,139,157,179,212,237,252]
imena = []
for i in vrstice:
    imena.append(gospodinstva_df.loc[i][0])
podatkiZInflacije = []
for i in vrstice:
    cena_z_inflacijo = [
    float(cena)  for cena, inflacija in zip(gospodinstva_df.loc[i][7:-1], inflacija_jan)]
    cena_z_inflacijo.insert(0, gospodinstva_df.loc[i][6])
    podatkiZInflacije.append(cena_z_inflacijo)



sumBrezInflacije = []
sumZInflacije = []
for x in podatkiBrezInflacije:
    sumBrezInflacije.append(sum(x))
sumBrezInflacije
for x in podatkiZInflacije:
    sumZInflacije.append(sum(x))


povprcjeBrezInflacije = [sum(sumBrezInflacije)/len(sumBrezInflacije)] * 2
povprcjeZInflacije = [sum(sumZInflacije)/len(sumZInflacije)] * 2

imena[3] = 'Stanovanja, voda, elektricna energija,\nplin in druga goriva'
imena[4] = 'Pohištvo, gospodinjska oprema in \ntekoce vzdrževanje gospodinjstev'

# %%
vecjeZ = []
vecjeBrez = []
imenaVecje = []
for i in [0,6,8]:
    vecjeBrez.append(sumBrezInflacije[i])
    vecjeZ.append(sumZInflacije[i])
    imenaVecje.append(imena[i])

# %%
manjseZ = []
manjseBrez = []
imenaManjse = []
for i in [1,2,3,4,5,7,9,10,11]:
    manjseBrez.append(sumBrezInflacije[i])
    manjseZ.append(sumZInflacije[i])
    imenaManjse.append(imena[i])

# %%
from matplotlib import gridspec

fig = plt.figure(figsize=(15, 8)) 
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 3]) 
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])


ind = np.arange(len(imenaVecje))
ax1.bar(ind, vecjeZ, 0.4, align="edge")

ax1.bar(ind-0.4, vecjeBrez,0.4, align="edge")

# ax1.plot([-0.4, 2.4], povprcjeBrezInflacije, color="green", label="Povprečje brez inflacije")
# ax1.plot([-0.4, 2.4], povprcjeZInflacije, color="black", label="Povprečje z inflacijo")

ax1.set(xlabel='Kategorija', ylabel='Poraba (mio €)')
ax1.set_xticks([0,1,2]) 
ax1.set_xticklabels(imenaVecje)
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)


ind = np.arange(len(imenaManjse))
plt.bar(ind,manjseZ, 0.4, align="edge", label="Z inflacijo")
plt.bar(ind-0.4,manjseBrez,0.4, align="edge", label="Brez inflacije")

ax2.set(xlabel='Kategorija', ylabel='Poraba (mio €)')
ax2.set_xticks([0,1,2,3,4,5,6,7,8]) 
ax2.set_xticklabels(imenaManjse)
for tick in ax2.get_xticklabels():
    tick.set_rotation(90)
    
    
fig.suptitle('Poraba po kategorijah čez leta z izključeno/vključeno inflacijo')
fig.legend()
plt.tight_layout()
fig.subplots_adjust(top=0.92)

plt.savefig('3.png')
plt.show()

# %%
manjseZ = []
manjseBrez = []
imenaManjse = []
for i in [1,2,3,4,5,7,9,10,11]:
    manjseBrez.append(sumBrezInflacije[i])
    manjseZ.append(sumZInflacije[i])
    imenaManjse.append(imena[i])



ind = np.arange(len(imenaManjse))
plt.figure(figsize=(15, 15))
plt.bar(ind,manjseZ, 0.4, align="edge", label="Z inflacijo")

plt.bar(ind-0.4,manjseBrez,0.4, align="edge", label="Brez inflacije")




plt.title('Poraba po kategorijah čez leta z izključeno/vključeno inflacijo')
plt.legend()
plt.xlabel('Kategorija')
plt.ylabel('Poraba (mio €)')
plt.xticks([0,1,2,3,4,5,6,7,8], imenaManjse, rotation='vertical')
plt.savefig('3_2.png')
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot()

for x in range(0,len(podatkiBrezInflacije)):
    ax.plot(podatkiBrezInflacije[x],label=imena[x])

ax.set_yscale("log")
plt.xlabel('Leto')
plt.ylabel('Poraba (mio €)')
plt.legend()
plt.show()

print()

# %%
inflacija_df = pd.read_csv('podatki/inflacija.csv', sep=',', header=1, encoding='windows-1250')
gospodinstva_df=pd.read_csv('podatki/gospodinstva.csv', sep=',',header=1)

inflacija_skupaj = inflacija_df.loc[0][13:] - 100

inflacija_jan = [inflacija_df.loc[0][i] / 100 for i in range(13, inflacija_df.loc[0][13:].size, 12)]

def calc_inflation(i, j):
    inflation = 1
    for k in range(i, j + 1):
        inflation *= inflacija_jan[k]
    return inflation * 100

inflacija_jan = [calc_inflation(0, i) - 100 for i in range(len(inflacija_jan))]
cena_z_inflacijo = [
    float(cena) - float(cena) * inflacija / 100 for cena, inflacija
                                                in zip(gospodinstva_df.loc[1][7:-1], inflacija_jan)
]
# add for year 1999 with no inflation included
cena_z_inflacijo.insert(0, gospodinstva_df.loc[1][6])
#cena_z_inflacijo

# %%
uvoz_izvoz = pd.read_csv('podatki/uvoz_izvoz.csv', sep=',',header=1)

skupen_uvoz_izvoz = uvoz_izvoz.loc[ (uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                (uvoz_izvoz['ACTIVITY'] == 'Activity - TOTAL')
              ].iloc[0, 3:]


letna_inflacija_2008_naprej = [inflacija_df.loc[0][i] / 100 for i in range(13, inflacija_df.loc[0][97:].size, 12)]

def calc_inflation(i, j):
    inflation = 1
    for k in range(i, j + 1):
        inflation *= letna_inflacija_2008_naprej[k]
    return inflation * 100

letna_inflacija_2008_naprej = [calc_inflation(0, i) - 100 for i in range(len(letna_inflacija_2008_naprej) - 1)]

leta = [str(leto) for leto in range(2008, 2019)]


uvoz_brez_inflacije = [uvoz - uvoz * inflacija / 100 for inflacija, uvoz in 
                       zip(letna_inflacija_2008_naprej, skupen_uvoz_izvoz.iloc[1::2])]

izvoz_brez_inflacije = [izvoz - izvoz * inflacija / 100 for inflacija, izvoz in 
                       zip(letna_inflacija_2008_naprej, skupen_uvoz_izvoz.iloc[::2])]


cena_z_inflacijo = cena_z_inflacijo[8:]
print(len(uvoz_brez_inflacije), len(cena_z_inflacijo))
# Out:
# 11 12

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

podatki = []
leto = 2008
for x, y in zip(cena_z_inflacijo, izvoz_brez_inflacije):
    podatki.append([x,y])
    leto += 1

# %%
color = {
    0: 'red',
    1: 'green',
}
kmeans = KMeans(n_clusters=2, random_state=0).fit(podatki)
# plt.figure(figsize=(10,10))
for c, x in zip(kmeans.labels_, podatki):
    plt.plot(x[0], x[1], ".", color=color[c], markersize=10.0)
plt.title('Gručenje glede na izvoz in štroške gospodinstva')
plt.xlabel('Gospodinstvo zapravili')
plt.ylabel('izvoz')
plt.show()

# %%
podatki = []
leto = 2008
for x, y in zip(cena_z_inflacijo, uvoz_brez_inflacije):
    podatki.append([x,y])
    leto += 1


color = {
    0: 'red',
    1: 'green',
}
kmeans = KMeans(n_clusters=2, random_state=0).fit(podatki)
plt.figure(figsize=(10,10))
for c, x in zip(kmeans.labels_, podatki):
    plt.plot(x[0], x[1], ".", color=color[c], markersize=10.0)
plt.title('Gručenje glede na uvoz in stroške gospodinjstev')
plt.xlabel('Gospodinstvo zapravili')
plt.ylabel('uvoz')
plt.show()

# %%
izbor1 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING'),  ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                                                                                           '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                                                                                           '2008 Imports']]
izbor2 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'A AGRICULTURE, FORESTRY AND FISHING'), ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                                                                                           '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                                                                                           '2008 Imports']]

izbor3 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'G WHOLESALE AND RETAIL TRADE, REPAIR OF MOTOR VEHICLES AND MOTORCYCLES'), 
                        ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                        '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                         '2008 Imports']]

izbor4 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'B_D_E  MINING AND QUARRYING, ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY, WATER SUPPLY, SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES'), 
                        ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                        '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                         '2008 Imports']]

izbor5 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == '9 OTHER ACTIVITIES'), 
                        ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                        '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                        '2008 Imports']]

uvoz1 = []
uvoz2 = []
uvoz3 = []
uvoz4 = []
uvoz5 = []
for i in range(0, len(izbor1)):
    uvoz1.extend((izbor1.iloc[i][0], izbor1.iloc[i][1], izbor1.iloc[i][2], izbor1.iloc[i][3], izbor1.iloc[i][4], 
                    izbor1.iloc[i][5], izbor1.iloc[i][6], izbor1.iloc[i][7], izbor1.iloc[i][8], 
                    izbor1.iloc[i][9], izbor1.iloc[i][10]))
    uvoz2.extend((izbor2.iloc[i][0], izbor2.iloc[i][1], izbor2.iloc[i][2], izbor2.iloc[i][3], izbor2.iloc[i][4], 
                    izbor2.iloc[i][5], izbor2.iloc[i][6], izbor2.iloc[i][7], izbor2.iloc[i][8], 
                    izbor2.iloc[i][9], izbor2.iloc[i][10]))
    uvoz3.extend((izbor3.iloc[i][0], izbor3.iloc[i][1], izbor3.iloc[i][2], izbor3.iloc[i][3], izbor3.iloc[i][4], 
                    izbor3.iloc[i][5], izbor3.iloc[i][6], izbor3.iloc[i][7], izbor3.iloc[i][8], 
                    izbor3.iloc[i][9], izbor3.iloc[i][10]))
    uvoz4.extend((izbor4.iloc[i][0], izbor4.iloc[i][1], izbor4.iloc[i][2], izbor4.iloc[i][3], izbor4.iloc[i][4], 
                    izbor4.iloc[i][5], izbor4.iloc[i][6], izbor4.iloc[i][7], izbor4.iloc[i][8], 
                    izbor4.iloc[i][9], izbor4.iloc[i][10]))
    uvoz5.extend((izbor5.iloc[i][0], izbor5.iloc[i][1], izbor5.iloc[i][2], izbor5.iloc[i][3], izbor5.iloc[i][4], 
                    izbor5.iloc[i][5], izbor5.iloc[i][6], izbor5.iloc[i][7], izbor5.iloc[i][8], 
                    izbor5.iloc[i][9], izbor5.iloc[i][10]))

stevilke = []
for i in range(2008, 2019):
    stevilke.append(i)

    

plt.figure(figsize=(20, 10))
plt.title("Primerjava uvoza različnih panog")
plt.plot(stevilke, uvoz1, label="C MANUFACTURING")
plt.plot(stevilke, uvoz2, label="A AGRICULTURE, FORESTRY AND FISHING")
plt.plot(stevilke, uvoz3, label="G WHOLESALE AND RETAIL TRADE, REPAIR OF MOTOR VEHICLES AND MOTORCYCLES")
plt.plot(stevilke, uvoz4, label="B_D_E  MINING AND QUARRYING, ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY, WATER SUPPLY, SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES")
plt.plot(stevilke, uvoz5, label="9 OTHER ACTIVITIES")
plt.xlabel('Leto')
plt.ylabel('Količina uvoza (1000 €)')
plt.legend()
plt.savefig('2_2.png')
plt.show()

# %%
izbor1 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING'), 
                        ["2008 Exports", "2009 Exports", "2010 Exports", "2011 Exports", "2012 Exports", "2013 Exports",
                         "2014 Exports", "2015 Exports", "2016 Exports", "2017 Exports", "2018 Exports"]]

izbor2 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'A AGRICULTURE, FORESTRY AND FISHING'), 
                        ["2008 Exports", "2009 Exports", "2010 Exports", "2011 Exports", "2012 Exports", "2013 Exports",
                         "2014 Exports", "2015 Exports", "2016 Exports", "2017 Exports", "2018 Exports"]]

izbor3 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'G WHOLESALE AND RETAIL TRADE, REPAIR OF MOTOR VEHICLES AND MOTORCYCLES'), 
                        ["2008 Exports", "2009 Exports", "2010 Exports", "2011 Exports", "2012 Exports", "2013 Exports",
                         "2014 Exports", "2015 Exports", "2016 Exports", "2017 Exports", "2018 Exports"]]

izbor4 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'B_D_E  MINING AND QUARRYING, ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY, WATER SUPPLY, SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES'), 
                        ["2008 Exports", "2009 Exports", "2010 Exports", "2011 Exports", "2012 Exports", "2013 Exports",
                         "2014 Exports", "2015 Exports", "2016 Exports", "2017 Exports", "2018 Exports"]]

izbor5 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == '9 OTHER ACTIVITIES'), 
                        ["2008 Exports", "2009 Exports", "2010 Exports", "2011 Exports", "2012 Exports", "2013 Exports",
                         "2014 Exports", "2015 Exports", "2016 Exports", "2017 Exports", "2018 Exports"]]

izvoz1 = []
for i in range(0, len(izbor1)):
    izvoz1.extend((izbor1.iloc[i][0], izbor1.iloc[i][1], izbor1.iloc[i][2], izbor1.iloc[i][3], izbor1.iloc[i][4], 
                    izbor1.iloc[i][5], izbor1.iloc[i][6], izbor1.iloc[i][7], izbor1.iloc[i][8], 
                    izbor1.iloc[i][9], izbor1.iloc[i][10]))

izvoz2 = []
for i in range(0, len(izbor2)):
    izvoz2.extend((izbor2.iloc[i][0], izbor2.iloc[i][1], izbor2.iloc[i][2], izbor2.iloc[i][3], izbor2.iloc[i][4], 
                    izbor2.iloc[i][5], izbor2.iloc[i][6], izbor2.iloc[i][7], izbor2.iloc[i][8], 
                    izbor2.iloc[i][9], izbor2.iloc[i][10]))

izvoz3 = []
for i in range(0, len(izbor3)):
    izvoz3.extend((izbor3.iloc[i][0], izbor3.iloc[i][1], izbor3.iloc[i][2], izbor3.iloc[i][3], izbor3.iloc[i][4], 
                    izbor3.iloc[i][5], izbor3.iloc[i][6], izbor3.iloc[i][7], izbor3.iloc[i][8], 
                    izbor3.iloc[i][9], izbor3.iloc[i][10]))
    
izvoz4 = []
for i in range(0, len(izbor4)):
    izvoz4.extend((izbor4.iloc[i][0], izbor4.iloc[i][1], izbor4.iloc[i][2], izbor4.iloc[i][3], izbor4.iloc[i][4], 
                    izbor4.iloc[i][5], izbor4.iloc[i][6], izbor4.iloc[i][7], izbor4.iloc[i][8], 
                    izbor4.iloc[i][9], izbor4.iloc[i][10]))
    
izvoz5 = []
for i in range(0, len(izbor5)):
    izvoz5.extend((izbor5.iloc[i][0], izbor5.iloc[i][1], izbor5.iloc[i][2], izbor5.iloc[i][3], izbor5.iloc[i][4], 
                    izbor5.iloc[i][5], izbor5.iloc[i][6], izbor5.iloc[i][7], izbor5.iloc[i][8], 
                    izbor5.iloc[i][9], izbor5.iloc[i][10]))
    
stevilke = []
for i in range(2008, 2019):
    stevilke.append(i)

# plt.figure(figsize=(25, 10))
plt.title("Primerjava izvoza različnih panog")
plt.plot(stevilke, izvoz1, label="Manufacturing")
plt.plot(stevilke, izvoz2, label="Agriculture, forestry, fishing")
plt.plot(stevilke, izvoz3, label="Wholesale and retail trade, repair of motor vehicles and motorcycles")
plt.plot(stevilke, izvoz4, label="Mining and quarrying, electricity, gas, steam and air conditioning supply, water supply, sewerage, waste management and remediation activities")
plt.plot(stevilke, izvoz5, label="9 other")
plt.ylabel('Količina izvoza (1000 €)')
plt.xlabel('Leto')
plt.legend()
plt.savefig('2_1.png')
plt.show()

a = np.average(izvoz1)
b = np.average(izvoz2)
c = np.average(izvoz3)
d = np.average(izvoz4)
e =np.average(izvoz5)

plt.figure(figsize = (8,5))
plt.bar(range(5), height=(a, b, c, d, e),
       tick_label=('1', '2', '3', '4', '5'),
       color = ('red', 'blue', 'gold', 'green', 'violet')) 
plt.xlabel("Panoga")
plt.ylabel("Povprečno število izvozov (10mio EUR)")


plt.show()

# %%
izborOstali = uvoz_izvoz.loc[uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL', ["2008 Exports","2008 Imports",
                                                                                     "2009 Exports","2009 Imports",
                                                                                     "2010 Exports","2010 Imports",
                                                                                     "2011 Exports","2011 Imports",
                                                                                     "2012 Exports","2012 Imports",
                                                                                     "2013 Exports","2013 Imports",
                                                                                     "2014 Exports","2014 Imports",
                                                                                     "2015 Exports","2015 Imports",
                                                                                     "2016 Exports","2016 Imports",
                                                                                     "2017 Exports","2017 Imports",
                                                                                     "2018 Exports","2018 Imports"]]

izborEu = uvoz_izvoz.loc[uvoz_izvoz['ECONOMIC GROUP'] == 'European Union (EU)', ["2008 Exports","2008 Imports",
                                                                                     "2009 Exports","2009 Imports",
                                                                                     "2010 Exports","2010 Imports",
                                                                                     "2011 Exports","2011 Imports",
                                                                                     "2012 Exports","2012 Imports",
                                                                                     "2013 Exports","2013 Imports",
                                                                                     "2014 Exports","2014 Imports",
                                                                                     "2015 Exports","2015 Imports",
                                                                                     "2016 Exports","2016 Imports",
                                                                                     "2017 Exports","2017 Imports",
                                                                                     "2018 Exports","2018 Imports"]]

izborNonM = uvoz_izvoz.loc[uvoz_izvoz['ECONOMIC GROUP'] == 'EU non-member countries', ["2008 Exports","2008 Imports",
                                                                                     "2009 Exports","2009 Imports",
                                                                                     "2010 Exports","2010 Imports",
                                                                                     "2011 Exports","2011 Imports",
                                                                                     "2012 Exports","2012 Imports",
                                                                                     "2013 Exports","2013 Imports",
                                                                                     "2014 Exports","2014 Imports",
                                                                                     "2015 Exports","2015 Imports",
                                                                                     "2016 Exports","2016 Imports",
                                                                                     "2017 Exports","2017 Imports",
                                                                                     "2018 Exports","2018 Imports"]]

izvozEu = []
izvozOstali = []
izvozNonM = []
st = []
for i in range(0, len(izborEu)):
    izvozEu.extend((izborEu.iloc[i][0], izborEu.iloc[i][2], izborEu.iloc[i][4], izborEu.iloc[i][6], izborEu.iloc[i][8], 
                    izborEu.iloc[i][10], izborEu.iloc[i][12],izborEu.iloc[i][14], izborEu.iloc[i][16], 
                    izborEu.iloc[i][18], izborEu.iloc[i][20]))
    izvozOstali.extend((izborOstali.iloc[i][0], izborOstali.iloc[i][2], izborOstali.iloc[i][4], izborOstali.iloc[i][6],
                    izborOstali.iloc[i][8], izborOstali.iloc[i][10], izborOstali.iloc[i][12],izborOstali.iloc[i][14],
                    izborOstali.iloc[i][16], izborOstali.iloc[i][18], izborOstali.iloc[i][20]))
    izvozNonM.extend((izborNonM.iloc[i][0], izborNonM.iloc[i][2], izborNonM.iloc[i][4], izborNonM.iloc[i][6],
                      izborNonM.iloc[i][8], izborNonM.iloc[i][10], izborNonM.iloc[i][12],izborNonM.iloc[i][14],
                      izborNonM.iloc[i][16], izborNonM.iloc[i][18], izborNonM.iloc[i][20]))
    
x = np.average(izvozEu)
y = np.average(izvozOstali)
z = np.average(izvozNonM)

plt.figure(figsize = (5,5))
plt.bar(range(2), height=(x,z),
       tick_label=('European Union (EU)', 'EU non-member countries'),
       color = ('red', 'blue')) 
plt.xlabel("Economic group")
plt.ylabel("Average number of exports (mio EUR)")
plt.show()

# %%
izbor1 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Top 1000') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING'),  ['2018 Imports', '2017 Imports', '2016 Imports', '2015 Imports','2014 Imports',
                                                                        '2013 Imports', '2012 Imports', '2011 Imports', '2010 Imports','2009 Imports',
                                                                        '2008 Imports']]
izbor2 = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') & 
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING'),  ['2018 Exports', '2017 Exports', '2016 Exports', '2015 Exports','2014 Exports',
                                                '2013 Exports', '2012 Exports', '2011 Exports', '2010 Exports','2009 Exports',
                                                '2008 Exports']]

uvoz = []
izvoz = []
for i in range(0, len(izbor1)):
    uvoz.extend((izbor1.iloc[i][0], izbor1.iloc[i][1], izbor1.iloc[i][2], izbor1.iloc[i][3], izbor1.iloc[i][4], 
                    izbor1.iloc[i][5], izbor1.iloc[i][6], izbor1.iloc[i][7], izbor1.iloc[i][8], 
                    izbor1.iloc[i][9], izbor1.iloc[i][10]))
    izvoz.extend((izbor2.iloc[i][0], izbor2.iloc[i][1], izbor2.iloc[i][2], izbor2.iloc[i][3], izbor2.iloc[i][4], 
                    izbor2.iloc[i][5], izbor2.iloc[i][6], izbor2.iloc[i][7], izbor2.iloc[i][8], 
                    izbor2.iloc[i][9], izbor2.iloc[i][10])) 
    
stevilke = []
for i in range(2008, 2019):
    stevilke.append(i)

    
plt.figure(figsize=(15, 6))
plt.title("Primerjava uvoz - izvoz za vsa leta za C MANUFACTURING")
plt.plot(stevilke, uvoz, label="Top 1000 izvozi za C MANUFACTURING")
plt.plot(stevilke, izvoz, label="Top 1000 uvozi za C MANUFACTURING")
plt.ylabel('Število uvozov/izvozov')
plt.legend()
plt.show()

# %%
plt.barh(range(5), width=(a, b, c, d, e),
        tick_label=('Manufacturing',
                   'Agriculture, forestry, fishing',
                   'Wholesale and retail trade, repair of vehicles', 
                   'Mining, electricity, gas, air conditioning supply,\n water supply, sewerage, waste management',
                   '9 others'),
        color=('red', 'blue', 'gold', 'green', 'violet')) 



plt.xlabel("Povprečno število izvozov v 10 milijonih")
plt.xticks(rotation='vertical')
plt.show()

# %%
leto = []
kolicina = []
for i, v in izbor1.iloc[0].items():
    leto.append(i.split(' ')[0])
    kolicina.append(v)

plt.plot(range(len(kolicina)), kolicina, label='Izvoz')
plt.xticks(range(len(leto)), leto)
plt.ylabel('Količina v 10 milijonih')
plt.xlabel('Leto')
plt.title('Izvoz na področju proizvodnje')
plt.legend()
plt.show()

# %%
manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING')]
manufacturing = manufacturing.iloc[0, 3:] # skip groups

# %%
leto_m = set()
uvoz_m = []
izvoz_m = []
for i, v in manufacturing.items():
    # izvozi
    if 'Exports' in i:
        izvoz_m.append(v)
    # uvozi
    else:
        uvoz_m.append(v)
    # leto je itak isto
    leto_m.add(i.split(' ')[0])

# brez dvojnih
leto_m = sorted(list(set(leto_m)))

# %%
plt.plot(range(len(leto_m)), izvoz_m, label='Izvoz')
plt.plot(range(len(leto_m)), uvoz_m, label='Uvoz')
plt.xticks(range(len(leto_m)), leto_m)
plt.ylabel('Količina v 10 milijonih')
plt.xlabel('Leto')
plt.title('Uvoz in izvoz na področju proizvodnje')
plt.legend()
plt.show()

# %%
agro_forest_fish = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'A AGRICULTURE, FORESTRY AND FISHING')]
agro_forest_fish = agro_forest_fish.iloc[0, 3:]

# %%
leto_agr = set()
uvoz_agr = []
izvoz_agr = []
for i, v in agro_forest_fish.items():
    # izvozi
    if 'Exports' in i:
        izvoz_agr.append(v)
    # uvozi
    else:
        uvoz_agr.append(v)
    # leto je itak isto
    leto_agr.add(i.split(' ')[0])

# brez dvojnih
leto_agr = sorted(list(set(leto_agr)))

# %%
plt.plot(range(len(leto_agr)), izvoz_agr, label='Izvoz')
plt.plot(range(len(leto_agr)), uvoz_agr, label='Uvoz')
plt.xticks(range(len(leto_agr)), leto_agr)
plt.ylabel('Količina')
plt.xlabel('Leto')
plt.title('Uvoz in izvoz na področju agrokulture, gozdarstva in ribištva')
plt.legend()
plt.show()

# %%
from array import *
import scipy.cluster.hierarchy as sch
import scipy

# %%
manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'A AGRICULTURE, FORESTRY AND FISHING')]
ena = manufacturing.iloc[0, 3:] # skip groups
#print(ena)

manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'B_D_E  MINING AND QUARRYING, ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY, WATER SUPPLY, SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES')]
dva = manufacturing.iloc[0, 3:] # skip groups
#print(dva)

manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'C MANUFACTURING')]
tri = manufacturing.iloc[0, 3:] # skip groups
#print(tri)

manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == 'G WHOLESALE AND RETAIL TRADE, REPAIR OF MOTOR VEHICLES AND MOTORCYCLES')]
stiri = manufacturing.iloc[0, 3:] # skip groups
#print(stiri)

manufacturing = uvoz_izvoz.loc[(uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                        (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                        (uvoz_izvoz['ACTIVITY'] == '9 OTHER ACTIVITIES')]
pet = manufacturing.iloc[0, 3:] # skip groups
#print(pet)

# %%
matrikaIzvoz = np.zeros((5, 11))
j = 0
seznam = []
for i, v in ena.items():
    if 'Exports' in i:
        matrikaIzvoz[0][j] = int(v)
        j += 1

j = 0
for i, v in dva.items():
    if 'Exports' in i:
        matrikaIzvoz[1][j] = int(v)
        j += 1

j = 0
for i, v in tri.items():
    if 'Exports' in i:
        matrikaIzvoz[2][j] = int(v)
        j += 1

j = 0
for i, v in stiri.items():
    if 'Exports' in i:
        matrikaIzvoz[3][j] = int(v)
        j += 1
        
j = 0
for i, v in pet.items():
    if 'Exports' in i:
        matrikaIzvoz[4][j] = int(v)
        j += 1

# %%
seznam = ["A AGRICULTURE, FORESTRY AND FISHING", "B_D_E  MINING AND QUARRYING, ELECTRICITY, \nGAS, STEAM AND AIR CONDITIONING SUPPLY, \nWATER SUPPLY, SEWERAGE, WASTE MANAGEMENT \nAND REMEDIATION ACTIVITIES", "C MANUFACTURING", "G WHOLESALE AND RETAIL TRADE, \nREPAIR OF MOTOR VEHICLES AND MOTORCYCLES", "9 OTHER ACTIVITIES"]
L = sch.linkage(matrikaIzvoz, method="average", metric="cityblock")
plt.figure(figsize=(15, 7))
D = sch.dendrogram(L, labels=seznam, leaf_font_size=15, orientation="left")
plt.xlabel("Razdalja")
plt.title('Gručenje panog glede na izvoz')
plt.tight_layout()
plt.savefig('4_2.png')
plt.show()

# %%
matrikaUvoz = np.zeros((5, 11))
j = 0
seznam = []
for i, v in ena.items():
    if 'Imports' in i:
        matrikaUvoz[0][j] = int(v)
        j += 1

j = 0
for i, v in dva.items():
    if 'Imports' in i:
        matrikaUvoz[1][j] = int(v)
        j += 1

j = 0
for i, v in tri.items():
    if 'Imports' in i:
        matrikaUvoz[2][j] = int(v)
        j += 1

j = 0
for i, v in stiri.items():
    if 'Imports' in i:
        matrikaUvoz[3][j] = int(v)
        j += 1
        
j = 0
for i, v in pet.items():
    if 'Imports' in i:
        matrikaUvoz[4][j] = int(v)
        j += 1

# %%
seznam = ["A AGRICULTURE, FORESTRY AND FISHING", "B_D_E  MINING AND QUARRYING, ELECTRICITY, \nGAS, STEAM AND AIR CONDITIONING SUPPLY, \nWATER SUPPLY, SEWERAGE, WASTE MANAGEMENT \nAND REMEDIATION ACTIVITIES", "C MANUFACTURING", "G WHOLESALE AND RETAIL TRADE, \nREPAIR OF MOTOR VEHICLES AND MOTORCYCLES", "9 OTHER ACTIVITIES"]
L = sch.linkage(matrikaUvoz, method="average", metric="cityblock")
plt.figure(figsize=(15, 5))
D = sch.dendrogram(L, labels=seznam, leaf_font_size=15, orientation="left")
plt.xlabel("Razdalja")
plt.title('Gručenje panog glede na uvoz')
plt.tight_layout()
plt.savefig('4_1.png')
plt.show()

# %%
inflacija_df = pd.read_csv('podatki/inflacija.csv', sep=',', header=1, encoding='windows-1250')
inflacija_2008_naprej = inflacija_df.loc[0][97:]

# %%
letna_inflacija_2008_naprej = [inflacija_df.loc[0][i] / 100 for i in range(13, inflacija_df.loc[0][97:].size, 12)]

def calc_inflation(i, j):
    inflation = 1
    for k in range(i, j + 1):
        inflation *= letna_inflacija_2008_naprej[k]
    return inflation * 100

letna_inflacija_2008_naprej = [calc_inflation(0, i) - 100 for i in range(len(letna_inflacija_2008_naprej) - 1)]

leta = [str(leto) for leto in range(2008, 2019)]

# %%
plt.figure(figsize=(8, 5))
plt.plot(leta, letna_inflacija_2008_naprej)
plt.title('Inflacija od leta 2008 do 2019')
plt.xlabel('Leto')
plt.ylabel('Inflacija (%)')
plt.show()

# %%
skupen_uvoz_izvoz = uvoz_izvoz.loc[ (uvoz_izvoz['GROUP OF ENTERPRISES'] == 'Enterprises - TOTAL') &
                (uvoz_izvoz['ECONOMIC GROUP'] == 'Economic groups - TOTAL') &
                (uvoz_izvoz['ACTIVITY'] == 'Activity - TOTAL')
              ].iloc[0, 3:]

# %%
fig, ax1 = plt.subplots(figsize=(8,5))

ax1.set_xlabel('Leto')
ax1.set_ylabel('Uvoz / Izvoz (1000 €)')
ax1.plot(leta, skupen_uvoz_izvoz.iloc[::2], color='red', label='Izvoz')
ax1.plot(leta, skupen_uvoz_izvoz.iloc[1::2], color='green', label='Uvoz')
ax1.tick_params(axis='y')
plt.legend()

ax2 = ax1.twinx()
ax2.set_ylabel('Infacija (%)')
ax2.plot(leta, letna_inflacija_2008_naprej, color='blue', label='Inflacija')
ax2.tick_params(axis='y')

plt.legend(loc='lower right')
plt.title('Primerjava uvoza in izvoza z inflacijo')
plt.tight_layout()
plt.savefig('1.png')
plt.show()

# %%
uvoz_brez_inflacije = [uvoz - uvoz * inflacija / 100 for inflacija, uvoz in 
                       zip(letna_inflacija_2008_naprej, skupen_uvoz_izvoz.iloc[1::2])]

izvoz_brez_inflacije = [izvoz - izvoz * inflacija / 100 for inflacija, izvoz in 
                       zip(letna_inflacija_2008_naprej, skupen_uvoz_izvoz.iloc[::2])]

# %%
plt.figure(figsize=(8, 5))
plt.plot(leta, uvoz_brez_inflacije, label='Uvoz')
plt.plot(leta, izvoz_brez_inflacije, label='Izvoz')
plt.title('Uvoz in izvoz brez inflacije od leta 2008 do 2018')
plt.xlabel('Leto')
plt.ylabel('Uvoz/Izvoz (1000 €)')
plt.legend()
plt.show()
